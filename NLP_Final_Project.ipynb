# %% [markdown]
# Text

# %%
import os

from resources import parser

def parse_pdf(filepath):
    with open(filepath, "r") as f:
        for line in f.readlines():
            print(line)

base_path = os.path.join(os.getcwd(), "corpus")
filepaths = [os.path.join(base_path, f) for f in os.listdir(base_path)]

filepath = os.path.join(os.getcwd(), "23042200.J02.pdf")
parse_pdf(filepath)
# Out:
# ['',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  "השופטת ד' ברק-ארז:",
#  '',
#  '1.\tהעותר, שאינו מיוצג, מבקש בעתירתו מתן צווים "להפסקת הגבלת חירותו" ולהפסקת חקירות המתנהלות נגדו, לטענתו, על ידי השב"כ ומשטרת ישראל. ככל שניתן להבין, העתירה כוללת התייחסות לאירועים שהתרחשו, לדברי העותר, לפני שנים רבות, אף מחוץ לגבולות הארץ. יש לציין כי העתירה הוגשה בכתב יד והקריאה בה מעוררת קשיים.',
#  '',
#  '2.\tהעתירה, במתכונת שבה הוגשה, היא כוללנית למדי, אינה מניחה תשתית עובדתית או משפטית רלוונטית ולא ניתן להבין את הסעדים המבוקשים בה. ',
#  '',
#  '3. \tסוף דבר: העתירה נדחית על הסף. משלא התבקשה תגובה, אין צו להוצאות. ',
#  '',
#  '\tניתן היום, \u200fד\' בסיון התשפ"ג (\u200f24.5.2023).',
#  '',
#  '_________________________',
#  '   23039240_A01.docx   מנ',
#  "מרכז מידע, טל' 077-2703333, 3852* ; אתר אינטרנט,  ",
#  '']

# %%
base_path = os.path.join(os.getcwd(), "corpus")
filepaths = [os.path.join(base_path, f) for f in os.listdir(base_path)]

# %%
from resources import parser

filepath = filepaths[0]
parser.parse_doc(filepath)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 from resources import parser
#       3 filepath = filepaths[0]
# ----> 4 parser.parse_doc(filepath)
#
# File g:\האחסון שלי\Colab Notebooks\Natural_Language_Processing_10247\Homework\nlp_final_proj\resources\parser.py:12, in parse_doc(filepath)
#       9     text = para.text
#      11     if not text.isspace():
# ---> 12         paras.append("\n".join([" ".join(t.split() for t in text.split("\n"))]))
#      14 return paras
#
# TypeError: sequence item 0: expected str instance, list found
